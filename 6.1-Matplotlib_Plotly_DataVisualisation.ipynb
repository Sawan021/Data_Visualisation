# %% [markdown]
# ## MATPLOTLIB: Visualisation with Python

# %% [markdown]
# DATA VISUALISATION <br>
# It is used to give intermediate level data understanding based on some patterns in data.Data visualization is the representation of data through use of common graphics, such as charts, plots, infographics, and even animations. <br>
# These visual displays of information communicate complex data relationships and data-driven insights in a way that is easy to understand.
# (1)D.V is generally done for internal analysis to get some useful insights into the data.
# (2) Used for experimental purposes specially in case when ML algorithms are used.
#
# Dashboarding is different as it is generation of final insight of data like a report, which is generally done at the end of a project.
# It is created for external analysis or presentations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# %matplotlib inline   # To see graph in jupyter notebook console

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.rand(1000,1),index=pd.date_range('2022-09-06',periods=1000),columns=['data'])

# %%
df
# Out:
#                 data
# 2022-09-06  0.588131
# 2022-09-07  0.897714
# 2022-09-08  0.891531
# 2022-09-09  0.815837
# 2022-09-10  0.035890
# ...              ...
# 2025-05-28  0.992189
# 2025-05-29  0.756037
# 2025-05-30  0.299186
# 2025-05-31  0.261712
# 2025-06-01  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum()
# Out:
# 2022-09-06      0.588131
# 2022-09-07      1.485845
# 2022-09-08      2.377375
# 2022-09-09      3.193213
# 2022-09-10      3.229102
#                  ...
# 2025-05-28    495.812936
# 2025-05-29    496.568973
# 2025-05-30    496.868159
# 2025-05-31    497.129872
# 2025-06-01    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df.data.cumsum().plot()

#data set appears to be flat
# Out:
# <AxesSubplot:>

# %%
df['data1']=df.data.cumsum()

# %%
df['data2']=df['data'].apply(lambda x: x*3)
df
# Out:
#                 data       data1     data2
# 2022-09-06  0.588131    0.588131  1.764392
# 2022-09-07  0.897714    1.485845  2.693141
# 2022-09-08  0.891531    2.377375  2.674592
# 2022-09-09  0.815837    3.193213  2.447512
# 2022-09-10  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2025-05-28  0.992189  495.812936  2.976566
# 2025-05-29  0.756037  496.568973  2.268112
# 2025-05-30  0.299186  496.868159  0.897559
# 2025-05-31  0.261712  497.129872  0.785137
# 2025-06-01  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df1= sns.load_dataset('iris')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(figsize=(5,5),title="Iris Data")
# Out:
# <AxesSubplot:title={'center':'Iris Data'}>

# %%
gf=df1.plot(figsize=(5,5),title="Iris Data")
gf.set_xlabel("X-axis")
gf.set_ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
df1.iloc[0][0:4].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2=sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df3
# Out:
#           a         b         c         d
# 0  0.534850  0.141536  0.997549  0.663146
# 1  0.310007  0.127744  0.547494  0.029529
# 2  0.344711  0.929877  0.579118  0.643341
# 3  0.557322  0.307009  0.887460  0.760641
# 4  0.249756  0.648684  0.123295  0.508399
# 5  0.174770  0.759351  0.493705  0.254648
# 6  0.393292  0.008692  0.296240  0.232336
# 7  0.841515  0.442961  0.656447  0.080341
# 8  0.719348  0.575515  0.577130  0.251678
# 9  0.166954  0.675000  0.177515  0.724717

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Histogram: Represents occurences of a Range (x-axis) with its frequency (y-axis)
# Bar Graph: Represents categorical data using rectangular bars where the length of each bar is proportional to the value they represent.

# %%
df1['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind='hist',stacked=True, bins=100,figsize = (10,10) , title = "histogram of iris")

# bins is width
# Out:
# <AxesSubplot:title={'center':'histogram of iris'}, ylabel='Frequency'>

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (10,10) , title = "histogram of iris" ,orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'histogram of iris'}, xlabel='Frequency'>

# %%
df1.hist(figsize= (10,10) , color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize= (10,10) , color = '#66ff99')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize= (10,10) , color = 'r' , alpha  = .3)

#alpha contrast increasing as move towards 1.
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# understanding relationship between parameters SCATTER PLOT is used

# in case of this plot we need to set axis

df1.plot.scatter(x='sepal_width',y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_width',y='petal_width', c='petal_length')

#Here we are seeing relationship b/w x and y with color variation due to c
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',label='skm',s=60,color='g')

#size controls radius of these dots
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x='sepal_length',y='sepal_width',label='skm',gridsize=7,color='g')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
d = df.iloc[0]
d
# Out:
# data     0.588131
# data1    0.588131
# data2    1.764392
# Name: 2022-09-06 00:00:00, dtype: float64

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2022-09-06 00:00:00'>

# %%
df1.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris= df.head(3).T

# %%
iris.iloc[0:4]
# Out:
#        2022-09-06  2022-09-07  2022-09-08
# data     0.588131    0.897714    0.891531
# data1    0.588131    1.485845    2.377375
# data2    1.764392    2.693141    2.674592

# %%
iris.iloc[0:4].plot.pie(subplots=True, figsize=(15,15))
# Out:
# array([<AxesSubplot:ylabel='2022-09-06 00:00:00'>,
#        <AxesSubplot:ylabel='2022-09-07 00:00:00'>,
#        <AxesSubplot:ylabel='2022-09-08 00:00:00'>], dtype=object)

# %%
iris.iloc[0:4].plot.pie(subplots=True, figsize=(15,15),fontsize=16, autopct='%.2f')

#autopct shows the details of area
# Out:
# array([<AxesSubplot:ylabel='2022-09-06 00:00:00'>,
#        <AxesSubplot:ylabel='2022-09-07 00:00:00'>,
#        <AxesSubplot:ylabel='2022-09-08 00:00:00'>], dtype=object)

# %%
pd.plotting.scatter_matrix(df1, figsize=(10,10),color='r')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
#now if we want curve instead of histogram in diagonal elements then use kde(kernel density estimate)

pd.plotting.scatter_matrix(df1, figsize=(10,10),color='r', diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df['data'].plot(style='r--', legend=True, label='skm')
# Out:
# <AxesSubplot:>

# %%
df['data'].plot(style='r*', legend=True, label='skm')
# Out:
# <AxesSubplot:>

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002614E62F640>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/1a/18/4d32edaaf31ba4af9745dac676c4a28c48d3fc539000c29e855bd8db3b86/cufflinks-0.17.3.tar.gz
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002614E62F790>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/1a/18/4d32edaaf31ba4af9745dac676c4a28c48d3fc539000c29e855bd8db3b86/cufflinks-0.17.3.tar.gz
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68727 sha256=1f28843d6e38092420595f6339dc2af20d618e34ca794488b24e2f3eead4ddd3
# ...

# %%
#plolty is specially used for a variety of graphs
#cufflinks is just a configuration file

# %%
from plotly.offline import iplot
import plotly as py 
import plotly.tools as tls 
import cufflinks as cf

# %%
py.__version__

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.iplot()

#will show error as we are going to plot this online but plotly is available offline
# Out:
# ---------------------------------------------------------------------
# ModuleNotFoundError                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430                 try:
# -> 1431                         import chart_studio.plotly as py
#    1432                 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                           Traceback (most recent call last)
# <ipython-input-89-b5f0fdeba0d6> in <module>
# ----> 1 df1.iplot()
#       2
#       3 #will show error as we are going to plot this online but plotly is available offline
#
# ...

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df1.iplot()
# Out:
# <div>                            <div id="8f24d609-ffcc-4208-b532-d162cbb253b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Plotly is very strong tool specially when we use Export to plotly option, nd on online version we can make changes itself.
#
# Here is the link to it: https://plot.ly/create/
# TibcoSpotfire is heavily used in Energy, oil/gas , supply chain industry

# %%
#iplot is used for plotly library
df2.iplot(x = 'fare' , y = 'age',kind = 'scatter')
# Out:
# <div>                            <div id="1db05a5e-798a-4b47-9343-d6aaae101b40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(x = 'fare' , y = 'age',kind = 'scatter' ,mode = 'markers',xTitle= 'fare' , yTitle = 'age')
# Out:
# <div>                            <div id="e9f19243-027e-4773-a257-62741d3a59a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
cf.set_config_file(theme='polar')
df2.iplot(x = 'fare' , y = 'age',kind = 'scatter' ,mode = 'markers',xTitle= 'fare' , yTitle = 'age')
# Out:
# <div>                            <div id="7720307e-c916-4407-9d2e-78cc266a53bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.set_config_file(theme='solar')
df2.iplot(x = 'fare' , y = 'age',kind = 'scatter' ,mode = 'markers',xTitle= 'fare' , yTitle = 'age')
# Out:
# <div>                            <div id="c721c93b-6346-4641-a151-4cacc70d2a56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## THANK YOU & KEEP LEARNING
